# %% [markdown]
# <h1 class="list-group-item list-group-item-action active" data-toggle="list"  role="tab" aria-controls="home">Exploratory Data Analysis Mini Project </h1>

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# <h4 class="list-group-item list-group-item-action active" >1. DESCRIPTIVE STATISTICS</h4>
#
# >#### 1. Create a dataframe using below data and answer the below questions:
#
#         Hourly_Income = [1000,2009,24418,444478,324235,243242,3434234,7567457,9235,238237,1312,3412]
#         Hourly_Expense =  [651361,217371,2746,2356,13436,5732,346346,3463,1132,23534,242235,235235]
#         family_members_count = [3,4,2,3,1,4,5,6,3,6,3,5]
#         House_rent = [1299,2300,3411,3422,4566,4211,4600,736,672,0,734,2374]
#         Highest_income_Member = ["Olivia","George","Isla","Harry","Ava","Noah","Sophia","Jacobi","Freddie","Ella","Grace","Ella"]
#
#
# >##### A. Display the five point summary of the data.
# >##### B. What is the mean of the hourly expense?
# >##### C. What is the median of the hourly expense?
# >##### D. Find the family member with maximum income and using a suitable graph.
# >##### E. Calculate IQR(the difference between 75% and 25% quartile) for `Hourly_Income` and `Hourly_Expense`.
# >##### F. Calculate the standard deviation for first 2 columns.
# >##### G. Calculate variance for the first 4 columns

# %%
Hourly_Income =[1000,2009,24418,444478,324235,243242,3434234,7567457,9235,238237,1312,3412]
Hourly_Expense =  [651361,217371,2746,2356,13436,5732,346346,3463,1132,23534,242235,235235]
family_members_count = [3,4,2,3,1,4,5,6,3,6,3,5]
House_rent = [1299,2300,3411,3422,4566,4211,4600,736,672,0,734,2374]
Highest_income_Member = ["Olivia","George","Isla","Harry","Ava","Noah","Sophia","Jacobi","Freddie","Ella","Grace","Ella"]

# %%
df1= pd.DataFrame({'Hourly_Income':Hourly_Income,
                   'Hourly_Expense':Hourly_Expense,
                   'family_members_count':family_members_count,
                   'House_rent': House_rent,
                   'Highest_income_Member':Highest_income_Member})
df1.head()
# Out:
#    Hourly_Income  Hourly_Expense  family_members_count  House_rent  \
# 0           1000          651361                     3        1299
# 1           2009          217371                     4        2300
# 2          24418            2746                     2        3411
# 3         444478            2356                     3        3422
# 4         324235           13436                     1        4566
#
#   Highest_income_Member
# 0                Olivia
# 1                George
# 2                  Isla
# 3                 Harry
# 4                   Ava

# %% [markdown]
# ## A. Display the five point summary of the data.

# %%
df1.describe()
# Out:
#        Hourly_Income  Hourly_Expense  family_members_count   House_rent
# count   1.200000e+01       12.000000             12.000000    12.000000
# mean    1.024439e+06   145412.250000              3.750000  2360.416667
# std     2.274083e+06   202831.565333              1.544786  1661.663813
# min     1.000000e+03     1132.000000              1.000000     0.000000
# 25%     3.061250e+03     3283.750000              3.000000   735.500000
# 50%     1.313275e+05    18485.000000              3.500000  2337.000000
# 75%     3.542958e+05   236985.000000              5.000000  3619.250000
# max     7.567457e+06   651361.000000              6.000000  4600.000000

# %%
 df1.describe(include='object')
# Out:
#        Highest_income_Member
# count                     12
# unique                    11
# top                     Ella
# freq                       2

# %%
plt.hist(df1['family_members_count'],bins=5)
plt.axvline(df1['family_members_count'].mean(),color='red')
plt.axvline(df1['family_members_count'].median(),color='orange')
plt.axvline(df1['family_members_count'].mode()[0],color='yellow')

# %%
plt.hist(df1['House_rent'],bins=10)
plt.axvline(df1['House_rent'].mean(),color='red')
plt.axvline(df1['House_rent'].median(),color='black')
plt.axvline(df1['House_rent'].mode()[0],color='yellow')
plt.text()

# %%
df1_num= df1.select_dtypes(include=np.number)
df1_num.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Hourly_Income'}>,
#         <AxesSubplot:title={'center':'Hourly_Expense'}>],
#        [<AxesSubplot:title={'center':'family_members_count'}>,
#         <AxesSubplot:title={'center':'House_rent'}>]], dtype=object)

# %%
df1_num.plot(kind='box',subplots=True,layout=(2,2))
plt.tight_layout()

# %%
sns.color_palette("Set2",10)
# Out:
# [(0.4, 0.7607843137254902, 0.6470588235294118),
#  (0.9882352941176471, 0.5529411764705883, 0.3843137254901961),
#  (0.5529411764705883, 0.6274509803921569, 0.796078431372549),
#  (0.9058823529411765, 0.5411764705882353, 0.7647058823529411),
#  (0.6509803921568628, 0.8470588235294118, 0.32941176470588235),
#  (1.0, 0.8509803921568627, 0.1843137254901961),
#  (0.8980392156862745, 0.7686274509803922, 0.5803921568627451),
#  (0.7019607843137254, 0.7019607843137254, 0.7019607843137254),
#  (0.4, 0.7607843137254902, 0.6470588235294118),
#  (0.9882352941176471, 0.5529411764705883, 0.3843137254901961)]

# %%
pd.to_numeric(df1_num['House_rent'])
# Out:
# 0     1299
# 1     2300
# 2     3411
# 3     3422
# 4     4566
# 5     4211
# 6     4600
# 7      736
# 8      672
# 9        0
# 10     734
# 11    2374
# Name: House_rent, dtype: int64

# %%
df1.dtypes
# Out:
# Hourly_Income             int64
# Hourly_Expense            int64
# family_members_count      int64
# House_rent                int64
# Highest_income_Member    object
# dtype: object

# %% [markdown]
# ## B.  What is the mean of the hourly expense?

# %%
hr_exp_mean=df1['Hourly_Expense'].mean()
print('The mean of Hourly expense is :: ',hr_exp_mean)
# Out:
# The mean of Hourly expense is ::  145412.25

# %% [markdown]
# ## C. What is the median of the hourly expense?

# %%
hr_exp_median=df1['Hourly_Expense'].median()
print('The median of Hourly expense is :: ',hr_exp_median)
# Out:
# The median of Hourly expense is ::  18485.0

# %% [markdown]
# ## D. Find the family member with maximum income and using a suitable graph.

# %%
df1.describe(include='object')
# Out:
#        Highest_income_Member
# count                     12
# unique                    11
# top                     Ella
# freq                       2

# %%
sns.countplot(x='Highest_income_Member',data=df1)
# Out:
# <AxesSubplot:xlabel='Highest_income_Member', ylabel='count'>

# %% [markdown]
# ###  E. Calculate IQR(the difference between 75% and 25% quartile) for Hourly_Income and Hourly_Expense.

# %%
IQR=df1['Hourly_Income'].quantile(0.75)-df1['Hourly_Income'].quantile(0.25)
IQR
# Out:
# 351234.5

# %%
q1=df1['Hourly_Income'].quantile(0.25)
q3=df1['Hourly_Income'].quantile(0.75)
hr_In_IQR=q3-q1
print('The IQR of Hourly Income is :: ',hr_In_IQR)
# Out:
# The IQR of Hourly Income is ::  351234.5

# %%
sns.violinplot(data=df1,x='Hourly_Income')
# Out:
# <AxesSubplot:xlabel='Hourly_Income'>

# %%
sns.boxplot(data=df1,x='Hourly_Income')
# contain extreme values
# Out:
# <AxesSubplot:xlabel='Hourly_Income'>

# %%
q1=df1['Hourly_Expense'].quantile(0.25)
q3=df1['Hourly_Expense'].quantile(0.75)
hr_exp_IQR=q3-q1
print('The IQR of Hourly expense is :: ',hr_exp_IQR)
# Out:
# The IQR of Hourly expense is ::  233701.25

# %%
sns.boxplot(data=df1,x='Hourly_Expense')
# contain extreme value
# Out:
# <AxesSubplot:xlabel='Hourly_Expense'>

# %% [markdown]
# ## F.Calculate the standard deviation for first 2 columns.

# %%
print('Hourly_Income ::',df1['Hourly_Income'].std())
print('Hourly_Expense ::',df1['Hourly_Expense'].std())
# Out:
# Hourly_Income :: 2274082.7497064094
# Hourly_Expense :: 202831.56533265588

# %% [markdown]
# ## G. Calculate variance for the first 4 columns

# %%
df1.var()
# Out:
# Hourly_Income           5.171452e+12
# Hourly_Expense          4.114064e+10
# family_members_count    2.386364e+00
# House_rent              2.761127e+06
# dtype: float64

# %% [markdown]
# <h4 class="list-group-item list-group-item-action active" >2. Preliminary Wrangling,</h4>
#
# >### Dataset Information:
#
# Dataset recording people to invest in each other in a way that is financially and socially rewarding. On loans, borrowers list loan requests between $ 2,000 and $ 35,000 and individual investors invest as little as $ 25 in each loan listing they select. Prosper handles the servicing of the loan on behalf of the matched borrowers and investors.
#
#
#
#
# >#### A. Read the dataset called Pri-Load.csv
# >#### B.  Check the data type and adjust datatype for all other categorical columns.
# >#### C. If you find any of the missing values in the ProsperRating column, then drop it.

# %% [markdown]
# ## A. Read the dataset called Pri-Load.csv

# %%
df2= pd.read_csv('Pri-Load.csv')

# %%
df2.head()
df2.shape
# Out:
# (1035, 22)

# %% [markdown]
# ## B. Check the data type and adjust datatype for all other categorical columns.

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ListingCreationDate        1035 non-null   object
#  1   Term                       1035 non-null   int64
#  2   LoanStatus                 1035 non-null   object
#  3   ClosedDate                 479 non-null    object
#  4   BorrowerAPR                1035 non-null   float64
#  5   BorrowerRate               1035 non-null   float64
#  6   LenderYield                1035 non-null   float64
#  7   ProsperRating (Alpha)      783 non-null    object
#  8   ProsperScore               783 non-null    float64
#  9   ListingCategory (numeric)  1035 non-null   int64
#  10  BorrowerState              983 non-null    object
#  11  Occupation                 996 non-null    object
#  12  EmploymentStatus           1010 non-null   object
#  13  AmountDelinquent           954 non-null    float64
#  14  StatedMonthlyIncome        1035 non-null   float64
#  15  LoanCurrentDaysDelinquent  1035 non-null   int64
#  16  LoanOriginalAmount         1035 non-null   int64
#  17  LoanOriginationDate        1035 non-null   object
#  18  LoanOriginationQuarter     1035 non-null   object
#  19  MonthlyLoanPayment         1035 non-null   float64
#  20  LP_InterestandFees         1035 non-null   float64
#  21  Investors                  1035 non-null   int64
# dtypes: float64(8), int64(5), object(9)
# memory usage: 178.0+ KB

# %%
df2.dtypes
# Out:
# ListingCreationDate           object
# Term                           int64
# LoanStatus                    object
# ClosedDate                    object
# BorrowerAPR                  float64
# BorrowerRate                 float64
# LenderYield                  float64
# ProsperRating (Alpha)         object
# ProsperScore                 float64
# ListingCategory (numeric)      int64
# BorrowerState                 object
# Occupation                    object
# EmploymentStatus              object
# AmountDelinquent             float64
# StatedMonthlyIncome          float64
# LoanCurrentDaysDelinquent      int64
# LoanOriginalAmount             int64
# LoanOriginationDate           object
# LoanOriginationQuarter        object
# MonthlyLoanPayment           float64
# LP_InterestandFees           float64
# Investors                      int64
# dtype: object

# %%
df2['Occupation'] = df2['Occupation'].astype('category')
df2['BorrowerState'] = df2['BorrowerState'].astype('category')
df2['LoanStatus'] = df2['LoanStatus'].astype('category')
df2['EmploymentStatus'] = df2['EmploymentStatus'].astype('category')
df2.dtypes
# Out:
# ListingCreationDate            object
# Term                            int64
# LoanStatus                   category
# ClosedDate                     object
# BorrowerAPR                   float64
# BorrowerRate                  float64
# LenderYield                   float64
# ProsperRating (Alpha)          object
# ProsperScore                  float64
# ListingCategory (numeric)       int64
# BorrowerState                category
# Occupation                   category
# EmploymentStatus             category
# AmountDelinquent              float64
# StatedMonthlyIncome           float64
# LoanCurrentDaysDelinquent       int64
# LoanOriginalAmount              int64
# LoanOriginationDate            object
# LoanOriginationQuarter         object
# MonthlyLoanPayment            float64
# LP_InterestandFees            float64
# Investors                       int64
# dtype: object

# %% [markdown]
# ## C. If you find any of the missing values in the ProsperRating column, then drop it.

# %%
df2['ProsperRating (Alpha)'].isna().sum()
# Out:
# 252

# %%
df2.dropna(subset=['ProsperRating (Alpha)'],inplace=True)
df2['ProsperRating (Alpha)'].isna().sum()
# Out:
# 0

# %%
df2.shape
# Out:
# (783, 22)

# %% [markdown]
# <h4 class="list-group-item list-group-item-action active" >3. UNIVARIATE ANALYSIS</h4>
#
# >#### A. What are the main features of interest in your dataset?
#
#     Step1: Apply Univariate analysis using suitable charts for[ Loan status, Employment Status, Stated Monthly Income]
#
#     Step2: Check if any column distribution skew or not.
#
#     Step3: Write at least 2 observations for each visualization.

# %% [markdown]
# #### Step1: Apply Univariate analysis using suitable charts for[ Loan status, Employment Status, Stated Monthly Income]

# %%
sns.countplot(y='LoanStatus',data=df2)
plt.show()

from matplotlib.pyplot import figure
figure(figsize=(8, 6), dpi=80)

df2['LoanStatus'].value_counts().plot(kind='pie',autopct='%1.1f%%')
plt.show()

# %%
sns.countplot(y='EmploymentStatus',data=df2)
plt.show()

from matplotlib.pyplot import figure
figure(figsize=(8, 6), dpi=80)

df2['EmploymentStatus'].value_counts().plot(kind='pie',autopct='%1.1f%%')
plt.show()

# %%
df2['StatedMonthlyIncome'].plot(kind='hist')
plt.show()

# %% [markdown]
# ### Step2: Check if any column distribution skew or not.

# %%
df2.skew() # skewness can not be checked for categorical data
# Out:
# Term                          0.634294
# BorrowerAPR                   0.146647
# BorrowerRate                  0.225834
# LenderYield                   0.225834
# ProsperScore                  0.149154
# ListingCategory (numeric)     2.002895
# AmountDelinquent             14.698357
# StatedMonthlyIncome           3.273664
# LoanCurrentDaysDelinquent     5.220228
# LoanOriginalAmount            1.103338
# MonthlyLoanPayment            1.246608
# LP_InterestandFees            2.058015
# Investors                     2.707363
# dtype: float64

# %% [raw]
# * We find that AmountDelinquent is skewed.
# * Here skew value is 3.2736637587476145
# * It is highly skewed

# %%
print('AmountDelinquent is skewed :: ',df2['AmountDelinquent'].skew())
# Out:
# AmountDelinquent is skewed ::  14.69835711369202

# %%
sns.boxplot(data=df2,x='AmountDelinquent')
# Out:
# <AxesSubplot:xlabel='AmountDelinquent'>

# %% [markdown]
# ### Step3: Write at least 2 observations for each visualization.

# %% [markdown]
# #### Loan status
# * 69 % falls under Current loans
# * 21.5 % has are completed states
#
# ####  Employment Status
# * We observe that 79 % of employess are employed
# * Out of which 8.8 % are full time employees
#
# ####  Stated Monthly Income
# * StatedMonthlyIncome is highly skewed.
# * There are quite alot of outliers and extreme value in this section
# * Majority of the value falls under 10000

# %%
print('skew:: ',df2['StatedMonthlyIncome'].skew())
print('Std :: ',df2['StatedMonthlyIncome'].std())
print('Mean:: ',df2['StatedMonthlyIncome'].mean())
print('Mode:: ',df2['StatedMonthlyIncome'].median())
# Out:
# skew::  3.2736637587476145
# Std ::  4277.335491185003
# Mean::  5996.674223049804
# Mode::  5000.0

# %% [markdown]
# <h4 class="list-group-item list-group-item-action active" >4. BIVARIATE ANALYSIS</h4>
#
# >#### A. Check the correlation matrix for all numeric variables. Maintain the Strong positive and Negative correlations columns.
# >#### B. Check the relation between `LoanOriginalAmount` and `BorrowerAPR` columns.
#
#     Step1: Use subplots.
#
#         Plot1: Scatter Plot of LoanOriginalAmount and BorrowerAPR columns
#
#         Plot2: HeatMap of LoanOriginalAmount and BorrowerAPR
#
#     Step2: Write your observations.
#
# >#### C.Display the seperate box plot for `y = BorrowerAPR`  with x1 = `LoanStatus`, x2 = `EmploymentStatus` columns.Write your observations.

# %% [markdown]
# #### A. Check the correlation matrix for all numeric variables. Maintain the Strong positive and Negative correlations columns.

# %%
from matplotlib.pyplot import figure

figure(figsize=(8, 6), dpi=80)
new_df2=df2.select_dtypes(include=np.number)
##sns.heatmap(new_df2.corr(),annot=True)
plt.title('Correlation Matrix for numerical values') 
sns.heatmap(new_df2.isnull(),annot=True,cbar=False)
plt.show()

# %% [markdown]
# #### B. Check the relation between LoanOriginalAmount and BorrowerAPR columns.

# %%
from matplotlib.pyplot import figure

figure(figsize=(8, 6), dpi=80)
sns.scatterplot(data=df2,x='LoanOriginalAmount',y='BorrowerAPR')
plt.title('Scatter Plot of LoanOriginalAmount and BorrowerAPR')
plt.show()

plt.hist2d(data = df2, x = 'LoanOriginalAmount', y = 'BorrowerAPR')
plt.show()

# %%
corr_=df2['LoanOriginalAmount'].corr(df2['BorrowerAPR'])
corr_
# Out:
# -0.422645598265228

# %%
df2_loan= pd.DataFrame(df2,columns=['LoanOriginalAmount','BorrowerAPR'])
sns.heatmap(df2_loan.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### C.Display the seperate box plot for y = BorrowerAPR with x1 = LoanStatus, x2 = EmploymentStatus columns.Write your observations

# %%
from matplotlib.pyplot import figure

figure(figsize=(18, 6), dpi=80)
sns.boxplot(data=df2,x='LoanStatus',y='BorrowerAPR')
# Out:
# <AxesSubplot:xlabel='LoanStatus', ylabel='BorrowerAPR'>

# %%
from matplotlib.pyplot import figure

figure(figsize=(18, 6), dpi=80)
sns.boxplot(data=df2,x='EmploymentStatus',y='BorrowerAPR')
# Out:
# <AxesSubplot:xlabel='EmploymentStatus', ylabel='BorrowerAPR'>

# %% [markdown]
# <h4 class="list-group-item list-group-item-action active" >5.  MULTI VARIATE ANALYSIS, FEATURE ENGINEERING</h4>
#
# >#### A. Write a program
#
#     Step 1: Create a  condition = 'LoanStatus'== 'Completed'| 'LoanStatus' == 'Defaulted' |\'LoanStatus' == 'Chargedoff'
#
#     Step2: Create a user define function  using condition and `LoanStatus` column.
#
#     Hint: df['LoanStatus'] = df.apply(user define function , axis=1)
#
#         Sample output :
#
#
#         Completed    168
#
#         Defaulted     59
#
#
# >#### B. Write a program
#
#     Step 1: Create a  dictionary called categories = 1: 'Debt Consolidation', 2: 'Home Improvement', 3: 'Business', 6: 'Auto', 7: 'Other'
#
#     Step2: Create a user define function  using categories and `ListingCategory (numeric)` column.
#
#     Hint: df['ListingCategory (numeric)'] = df.apply(user define function , axis=1)
#
#         Sample output :
#
#
#         Debt Consolidation    106
#
#         Other                  65
#
#         Business               25
#
#         Home Improvement       22
#
#         Auto                    9
#
# >#### C. Display the box plot for `ProsperRating (Alpha)` vs `LoanOriginalAmount` and hue = `Loan Status`[Completed,Defaulted]. Write your observations.
#
# >#### D. Display the catplot for `ProsperRating (Alpha)` vs `ListingCategory (numeric)`[Debt Consolidation,Other,Business,Home Improvement,Auto] and hue = `Loan Status`[Completed,Defaulted]. Write your observations.

# %%
condition = (df2['LoanStatus'] == 'Completed') | (df2['LoanStatus'] == 'Defaulted') |(df2['LoanStatus'] == 'Chargedoff')
df2 = df2[condition]
def to_defaulted(row):
    if row['LoanStatus'] == 'Chargedoff':
        return 'Defaulted'
    else:
        return row['LoanStatus']
    
df2['LoanStatus'] = df2.apply(to_defaulted, axis=1)
df2['LoanStatus'].value_counts()
# Out:
# Completed    168
# Defaulted     59
# Name: LoanStatus, dtype: int64

# %%
categories = {1: 'Debt Consolidation', 2: 'Home Improvement', 3: 'Business', 6: 'Auto', 7: 'Other'}
def UD_categorie(row):
    cat_ = row['ListingCategory (numeric)']
    if  cat_ in categories:
        return categories[cat_]
    else:
        return categories[7]
    
df2['ListingCategory (numeric)'] = df2.apply(UD_categorie, axis=1)
df2['ListingCategory (numeric)'].value_counts()
# Out:
# Debt Consolidation    106
# Other                  65
# Business               25
# Home Improvement       22
# Auto                    9
# Name: ListingCategory (numeric), dtype: int64

# %% [markdown]
# ##### C. Display the box plot for ProsperRating (Alpha) vs LoanOriginalAmount and hue = Loan Status[Completed,Defaulted]. Write your observations.

# %%
from matplotlib.pyplot import figure

figure(figsize=(10, 6), dpi=80)
sns.boxplot(data=df2, x='ProsperRating (Alpha)', y='LoanOriginalAmount', hue='LoanStatus');

# %% [markdown]
# ##### D. Display the catplot for ProsperRating (Alpha) vs ListingCategory (numeric)[Debt Consolidation,Other,Business,Home Improvement,Auto] and hue = Loan Status[Completed,Defaulted]. Write your observations.

# %%
sns.catplot(data=df2,x='ProsperRating (Alpha)',col='ListingCategory (numeric)', hue='LoanStatus',kind = 'count')
